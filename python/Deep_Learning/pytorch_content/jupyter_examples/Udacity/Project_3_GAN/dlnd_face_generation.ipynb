# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip
# Out:
# Archive:  processed_celeba_small.zip
# replace processed_celeba_small/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/0.4.0/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import DataLoader

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    
    transform = transforms.Compose([transforms.Resize(image_size),
                                     transforms.ToTensor()])
    
    image_path = "./" + data_dir
    dataset = datasets.ImageFolder(image_path, transform)
    
    dataloader = DataLoader(dataset, batch_size=batch_size,
                           shuffle=True, num_workers=0)
    
    
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 64
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = next(dataiter) # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, int(plot_size/2), idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    
    x = x * (feature_range[1] - feature_range[0]) + feature_range[0]
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-1.)
# Max:  tensor(0.9765)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv(in_channels, out_channels, filter_size, stride=2, padding=1, batch_norm=True):
    """ Function to create Convolution layer with a batch normalization layer if wanted
        :return: a Sequential Container with the defined layers
    """
    
    layers = []
    if batch_norm:
        # Creating Conv_2 without bias for batch norm
        conv_layer = nn.Conv2d(in_channels, out_channels, filter_size,
                              stride, padding, bias=False)
        layers.append(conv_layer)
        
        # Adding Batch norm Layer
        batch_layer = nn.BatchNorm2d(out_channels)
        layers.append(batch_layer)
        
    else:
        # Conv Layer with bias - no batch norm layer
        conv_layer = nn.Conv2d(in_channels, out_channels, filter_size,
                              stride, padding, bias=True)
        layers.append(conv_layer)
        
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        
        # Convolutional Layers with increasing depth
        self.conv_1 = conv(3, conv_dim, 4, batch_norm=False) # 16x16xconv_dim
        self.conv_2 = conv(conv_dim, conv_dim*2, 4) # 8x8xconv_dim*2
        self.conv_3 = conv(conv_dim*2, conv_dim*4, 4) # 4x4xconv_dim*4
        
        # Convolutional Layer which matches to the last layer to get one single output
        self.classifier = conv(conv_dim*4, 1, 4, stride=1, padding=0, batch_norm=False) # one value
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        
        x = F.relu(self.conv_1(x))
        x = F.relu(self.conv_2(x))
        x = F.relu(self.conv_3(x))  
        x = self.classifier(x)
        
        # need to reshape the output to get one value per batch item (batch_size, 1)
        return x.view(-1,1)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
# helper deconv function
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    t_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    
    # append conv layer
    layers.append(t_conv_layer)

    if batch_norm:
        # append batchnorm layer
        layers.append(nn.BatchNorm2d(out_channels))
     
    # using Sequential container
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()
        
        self.z_size = z_size
        self.conv_dim = conv_dim

        # complete init function
        
        self.fc = nn.Linear(z_size, conv_dim*4*4*4) 
        
        self.t_conv_1 = deconv(conv_dim*4, conv_dim*2, 4) # 4x4xconv_dimx4
        self.t_conv_2 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv_3 = deconv(conv_dim, 3, 4, batch_norm=False)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        
        x = self.fc(x)
        
        # Reshapening the output of the linear Layer for the first transposed conv layer.
        x = x.view(-1, self.conv_dim*4, 4, 4)
        
        x = F.relu(self.t_conv_1(x))
        x = F.relu(self.t_conv_2(x))
        x = F.tanh(self.t_conv_3(x))
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
from torch.nn import init

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    
    classname = m.__class__.__name__
    
    if (train_on_gpu):
    
        if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
            init.normal_(m.weight.data, 0.0, 0.02)
            
            if hasattr(m, 'bias') and m.bias is not None:
                init.constant_(m.bias.data, 0.0)

        elif classname.find('BatchNorm2d') != -1:  # BatchNorm Layer's weight is not a matrix; only normal distribution applies.
            init.normal_(m.weight.data, 1.0, 0.02)
            init.constant_(m.bias.data, 0.0)

    else:
            
        if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
            init.normal_(m.weight.data, 0.0, 0.02)

            if hasattr(m, 'bias') and m.bias is not None:
                init.constant_(m.bias.data, 0.0)

        elif classname.find('BatchNorm2d') != -1:  # BatchNorm Layer's weight is not a matrix; only normal distribution applies.
            init.normal_(m.weight.data, 1.0, 0.02)
            init.constant_(m.bias.data, 0.0)
        
    # TODO: Apply initial weights to convolutional and linear layers

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv_1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   )
#   (conv_2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv_3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Conv2d(256, 1, kernel_size=(4, 4), stride=(1, 1))
#   )
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=4096, bias=True)
#   (t_conv_1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv_2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv_3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    loss = torch.mean((D_out - 1) ** 2)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    loss = torch.mean(D_out ** 2)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

lr = 0.002
b1 = 0.5
b2 = 0.999

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [b1, b2])
g_optimizer = optim.Adam(G.parameters(), lr, [b1, b2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)
            
            if train_on_gpu:
                real_images = real_images.cuda()

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            
            # real images - calculating the real loss
            d_out_real = D(real_images)
            d_real_loss = real_loss(d_out_real)
            
            # creating latent vector z 
            z_vector = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z_vector = torch.from_numpy(z_vector).float()
            
            if train_on_gpu:
                z_vector = z_vector.cuda()
            
            # creating fake images from the Generator G
            fake_images = G(z_vector)
            
            # Calculating the loss for fake images
            d_out_fake = D(fake_images)
            d_fake_loss = fake_loss(d_out_fake)
            
            # Sum total D Loss and backprop
            d_loss = d_fake_loss + d_real_loss
            
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            
            g_optimizer.zero_grad()
            
            # creating latent vector z 
            z_vector = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z_vector = torch.from_numpy(z_vector).float()
            
            if train_on_gpu:
                z_vector = z_vector.cuda()
            
            # creating fake images from the Generator G
            fake_images = G(z_vector)
            
            D_fake = D(fake_images)
            
            g_loss = real_loss(D_fake)
            
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 20


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   20] | d_loss: 5.8063 | g_loss: 117.7759
# Epoch [    1/   20] | d_loss: 0.8452 | g_loss: 2.1509
# Epoch [    1/   20] | d_loss: 0.2354 | g_loss: 0.5721
# Epoch [    1/   20] | d_loss: 1.1643 | g_loss: 0.1232
# Epoch [    1/   20] | d_loss: 0.7444 | g_loss: 1.3928
# Epoch [    1/   20] | d_loss: 0.5240 | g_loss: 0.5750
# Epoch [    1/   20] | d_loss: 1.5495 | g_loss: 1.5247
# Epoch [    1/   20] | d_loss: 0.5888 | g_loss: 0.9059
# Epoch [    1/   20] | d_loss: 1.2548 | g_loss: 0.1736
# Epoch [    1/   20] | d_loss: 0.1013 | g_loss: 1.1799
# Epoch [    1/   20] | d_loss: 0.7165 | g_loss: 0.6793
# Epoch [    1/   20] | d_loss: 0.3365 | g_loss: 0.5296
# Epoch [    1/   20] | d_loss: 0.5061 | g_loss: 0.4818
# Epoch [    1/   20] | d_loss: 0.4326 | g_loss: 0.5727
# Epoch [    1/   20] | d_loss: 0.4011 | g_loss: 0.6242
# Epoch [    1/   20] | d_loss: 0.1290 | g_loss: 0.8593
# Epoch [    1/   20] | d_loss: 0.3307 | g_loss: 0.5925
# Epoch [    1/   20] | d_loss: 0.3605 | g_loss: 0.7510
# Epoch [    1/   20] | d_loss: 0.6866 | g_loss: 0.6468
# Epoch [    1/   20] | d_loss: 0.3016 | g_loss: 0.7269
# Epoch [    1/   20] | d_loss: 0.2738 | g_loss: 0.4543
# Epoch [    1/   20] | d_loss: 0.4925 | g_loss: 0.6207
# Epoch [    1/   20] | d_loss: 0.5280 | g_loss: 0.4402
# Epoch [    1/   20] | d_loss: 0.2484 | g_loss: 0.4561
# Epoch [    1/   20] | d_loss: 0.0917 | g_loss: 0.7641
# Epoch [    1/   20] | d_loss: 0.5111 | g_loss: 0.7113
# Epoch [    1/   20] | d_loss: 0.4059 | g_loss: 0.7284
# Epoch [    1/   20] | d_loss: 0.4200 | g_loss: 4.8386
# Epoch [    1/   20] | d_loss: 0.4195 | g_loss: 1.0657
# Epoch [    2/   20] | d_loss: 0.6867 | g_loss: 0.6973
# Epoch [    2/   20] | d_loss: 0.3568 | g_loss: 0.4026
# Epoch [    2/   20] | d_loss: 0.5429 | g_loss: 0.3572
# Epoch [    2/   20] | d_loss: 0.3207 | g_loss: 0.6112
# Epoch [    2/   20] | d_loss: 0.5713 | g_loss: 0.9225
# Epoch [    2/   20] | d_loss: 0.3095 | g_loss: 0.2519
# Epoch [    2/   20] | d_loss: 0.3138 | g_loss: 0.7985
# Epoch [    2/   20] | d_loss: 0.5827 | g_loss: 0.9489
# Epoch [    2/   20] | d_loss: 0.4663 | g_loss: 0.5146
# Epoch [    2/   20] | d_loss: 0.1597 | g_loss: 0.4453
# Epoch [    2/   20] | d_loss: 0.5413 | g_loss: 0.3475
# Epoch [    2/   20] | d_loss: 0.1371 | g_loss: 0.5931
# Epoch [    2/   20] | d_loss: 0.0285 | g_loss: 0.9267
# Epoch [    2/   20] | d_loss: 0.0318 | g_loss: 0.8711
# Epoch [    2/   20] | d_loss: 0.0133 | g_loss: 1.1771
# Epoch [    2/   20] | d_loss: 0.0364 | g_loss: 0.7197
# Epoch [    2/   20] | d_loss: 0.0111 | g_loss: 0.8534
# Epoch [    2/   20] | d_loss: 0.0441 | g_loss: 0.7296
# Epoch [    2/   20] | d_loss: 0.5643 | g_loss: 1.3645
# Epoch [    2/   20] | d_loss: 0.0673 | g_loss: 0.7930
# Epoch [    2/   20] | d_loss: 0.2922 | g_loss: 0.7927
# Epoch [    2/   20] | d_loss: 0.1612 | g_loss: 0.6557
# Epoch [    2/   20] | d_loss: 0.2752 | g_loss: 0.5971
# Epoch [    2/   20] | d_loss: 0.1441 | g_loss: 1.0971
# Epoch [    2/   20] | d_loss: 0.3079 | g_loss: 0.7092
# Epoch [    2/   20] | d_loss: 0.2134 | g_loss: 0.6157
# Epoch [    2/   20] | d_loss: 0.3609 | g_loss: 0.7022
# Epoch [    2/   20] | d_loss: 0.4351 | g_loss: 0.5500
# Epoch [    2/   20] | d_loss: 1.1199 | g_loss: 0.2777
# Epoch [    3/   20] | d_loss: 0.3189 | g_loss: 0.9215
# Epoch [    3/   20] | d_loss: 0.2902 | g_loss: 0.3600
# Epoch [    3/   20] | d_loss: 0.7329 | g_loss: 0.2167
# Epoch [    3/   20] | d_loss: 0.4519 | g_loss: 0.8747
# Epoch [    3/   20] | d_loss: 0.2766 | g_loss: 0.9617
# Epoch [    3/   20] | d_loss: 0.3024 | g_loss: 0.5174
# Epoch [    3/   20] | d_loss: 0.4150 | g_loss: 0.2529
# Epoch [    3/   20] | d_loss: 0.4127 | g_loss: 0.5532
# Epoch [    3/   20] | d_loss: 0.3495 | g_loss: 0.7818
# Epoch [    3/   20] | d_loss: 0.3543 | g_loss: 0.8207
# Epoch [    3/   20] | d_loss: 0.1808 | g_loss: 0.3887
# Epoch [    3/   20] | d_loss: 0.3348 | g_loss: 0.8174
# Epoch [    3/   20] | d_loss: 0.1936 | g_loss: 0.5064
# Epoch [    3/   20] | d_loss: 0.3795 | g_loss: 0.3696
# Epoch [    3/   20] | d_loss: 0.2610 | g_loss: 0.5318
# Epoch [    3/   20] | d_loss: 0.2562 | g_loss: 0.4299
# Epoch [    3/   20] | d_loss: 0.3017 | g_loss: 0.4844
# Epoch [    3/   20] | d_loss: 0.7774 | g_loss: 0.4111
# Epoch [    3/   20] | d_loss: 0.3251 | g_loss: 0.5395
# Epoch [    3/   20] | d_loss: 0.5008 | g_loss: 0.2844
# Epoch [    3/   20] | d_loss: 0.2469 | g_loss: 0.5736
# Epoch [    3/   20] | d_loss: 0.2691 | g_loss: 1.0546
# Epoch [    3/   20] | d_loss: 0.3526 | g_loss: 0.6896
# Epoch [    3/   20] | d_loss: 0.1657 | g_loss: 0.5089
# Epoch [    3/   20] | d_loss: 0.3359 | g_loss: 0.6607
# Epoch [    3/   20] | d_loss: 0.2483 | g_loss: 0.6625
# Epoch [    3/   20] | d_loss: 0.3013 | g_loss: 0.5303
# Epoch [    3/   20] | d_loss: 0.4949 | g_loss: 0.3114
# Epoch [    3/   20] | d_loss: 0.5209 | g_loss: 0.2827
# Epoch [    4/   20] | d_loss: 0.5623 | g_loss: 0.2585
# Epoch [    4/   20] | d_loss: 0.5377 | g_loss: 0.2647
# Epoch [    4/   20] | d_loss: 0.4418 | g_loss: 0.1999
# Epoch [    4/   20] | d_loss: 0.4513 | g_loss: 0.2776
# Epoch [    4/   20] | d_loss: 0.4685 | g_loss: 0.1833
# Epoch [    4/   20] | d_loss: 0.4793 | g_loss: 0.3478
# Epoch [    4/   20] | d_loss: 0.4849 | g_loss: 0.2379
# Epoch [    4/   20] | d_loss: 0.4906 | g_loss: 0.3044
# Epoch [    4/   20] | d_loss: 0.4518 | g_loss: 0.2514
# Epoch [    4/   20] | d_loss: 0.5979 | g_loss: 0.4707
# Epoch [    4/   20] | d_loss: 0.4924 | g_loss: 0.1798
# Epoch [    4/   20] | d_loss: 0.3918 | g_loss: 0.3235
# Epoch [    4/   20] | d_loss: 0.5665 | g_loss: 0.3273
# Epoch [    4/   20] | d_loss: 0.4341 | g_loss: 0.3449
# Epoch [    4/   20] | d_loss: 0.4742 | g_loss: 0.4456
# Epoch [    4/   20] | d_loss: 0.4440 | g_loss: 0.7099
# Epoch [    4/   20] | d_loss: 0.4535 | g_loss: 0.3100
# Epoch [    4/   20] | d_loss: 0.3488 | g_loss: 0.6255
# Epoch [    4/   20] | d_loss: 0.3586 | g_loss: 0.8878
# Epoch [    4/   20] | d_loss: 0.2773 | g_loss: 0.3863
# Epoch [    4/   20] | d_loss: 0.2691 | g_loss: 0.5218
# Epoch [    4/   20] | d_loss: 0.2892 | g_loss: 0.5021
# Epoch [    4/   20] | d_loss: 0.3118 | g_loss: 0.7677
# Epoch [    4/   20] | d_loss: 1.6478 | g_loss: 0.0754
# Epoch [    4/   20] | d_loss: 0.3597 | g_loss: 0.6782
# Epoch [    4/   20] | d_loss: 0.3532 | g_loss: 0.6841
# Epoch [    4/   20] | d_loss: 0.3495 | g_loss: 0.6341
# Epoch [    4/   20] | d_loss: 0.3797 | g_loss: 0.8591
# Epoch [    4/   20] | d_loss: 0.5460 | g_loss: 0.5190
# Epoch [    5/   20] | d_loss: 6.6693 | g_loss: 6.3453
# Epoch [    5/   20] | d_loss: 0.1578 | g_loss: 1.3372
# Epoch [    5/   20] | d_loss: 0.0847 | g_loss: 0.7677
# Epoch [    5/   20] | d_loss: 0.1971 | g_loss: 0.9973
# Epoch [    5/   20] | d_loss: 0.2647 | g_loss: 0.5700
# Epoch [    5/   20] | d_loss: 0.3307 | g_loss: 1.2348
# Epoch [    5/   20] | d_loss: 0.3813 | g_loss: 0.7046
# Epoch [    5/   20] | d_loss: 0.2793 | g_loss: 0.5192
# Epoch [    5/   20] | d_loss: 0.2357 | g_loss: 0.7426
# Epoch [    5/   20] | d_loss: 0.2329 | g_loss: 0.4388
# Epoch [    5/   20] | d_loss: 0.2758 | g_loss: 0.6764
# Epoch [    5/   20] | d_loss: 0.2774 | g_loss: 0.8465
# Epoch [    5/   20] | d_loss: 0.3399 | g_loss: 0.4938
# Epoch [    5/   20] | d_loss: 0.1756 | g_loss: 0.6468
# Epoch [    5/   20] | d_loss: 0.2168 | g_loss: 0.5930
# Epoch [    5/   20] | d_loss: 0.2599 | g_loss: 0.6717
# Epoch [    5/   20] | d_loss: 0.3813 | g_loss: 0.5719
# Epoch [    5/   20] | d_loss: 0.1670 | g_loss: 0.6321
# Epoch [    5/   20] | d_loss: 0.2047 | g_loss: 0.8040
# Epoch [    5/   20] | d_loss: 0.6807 | g_loss: 0.2058
# Epoch [    5/   20] | d_loss: 0.3504 | g_loss: 0.6245
# Epoch [    5/   20] | d_loss: 0.2800 | g_loss: 0.6708
# Epoch [    5/   20] | d_loss: 0.3114 | g_loss: 0.5742
# Epoch [    5/   20] | d_loss: 0.2958 | g_loss: 0.9089
# Epoch [    5/   20] | d_loss: 0.1758 | g_loss: 0.2510
# Epoch [    5/   20] | d_loss: 0.3635 | g_loss: 0.4709
# Epoch [    5/   20] | d_loss: 0.2622 | g_loss: 0.6918
# Epoch [    5/   20] | d_loss: 0.2919 | g_loss: 0.7777
# Epoch [    5/   20] | d_loss: 0.3371 | g_loss: 0.5873
# Epoch [    6/   20] | d_loss: 0.4434 | g_loss: 1.0608
# Epoch [    6/   20] | d_loss: 0.3446 | g_loss: 0.7951
# Epoch [    6/   20] | d_loss: 0.4919 | g_loss: 0.3837
# Epoch [    6/   20] | d_loss: 0.3780 | g_loss: 0.3422
# Epoch [    6/   20] | d_loss: 0.3253 | g_loss: 0.5041
# Epoch [    6/   20] | d_loss: 0.2950 | g_loss: 0.6483
# Epoch [    6/   20] | d_loss: 0.3356 | g_loss: 0.3157
# Epoch [    6/   20] | d_loss: 0.3290 | g_loss: 0.5506
# Epoch [    6/   20] | d_loss: 0.9214 | g_loss: 0.3030
# Epoch [    6/   20] | d_loss: 0.3083 | g_loss: 0.6551
# Epoch [    6/   20] | d_loss: 0.1981 | g_loss: 0.4001
# Epoch [    6/   20] | d_loss: 0.2139 | g_loss: 0.6867
# Epoch [    6/   20] | d_loss: 0.2616 | g_loss: 0.7348
# Epoch [    6/   20] | d_loss: 0.2676 | g_loss: 0.3816
# Epoch [    6/   20] | d_loss: 0.2521 | g_loss: 0.3574
# Epoch [    6/   20] | d_loss: 0.2654 | g_loss: 0.4612
# Epoch [    6/   20] | d_loss: 0.3534 | g_loss: 0.6514
# Epoch [    6/   20] | d_loss: 0.2463 | g_loss: 0.5225
# Epoch [    6/   20] | d_loss: 0.2451 | g_loss: 0.7183
# Epoch [    6/   20] | d_loss: 0.4287 | g_loss: 0.4487
# Epoch [    6/   20] | d_loss: 0.2852 | g_loss: 0.3787
# Epoch [    6/   20] | d_loss: 0.3136 | g_loss: 0.5422
# Epoch [    6/   20] | d_loss: 0.2006 | g_loss: 0.3987
# Epoch [    6/   20] | d_loss: 0.3902 | g_loss: 0.3037
# Epoch [    6/   20] | d_loss: 0.2261 | g_loss: 0.6235
# Epoch [    6/   20] | d_loss: 0.2912 | g_loss: 0.4745
# Epoch [    6/   20] | d_loss: 0.2897 | g_loss: 0.6656
# Epoch [    6/   20] | d_loss: 0.3292 | g_loss: 0.4242
# Epoch [    6/   20] | d_loss: 0.3018 | g_loss: 0.5724
# Epoch [    7/   20] | d_loss: 0.8058 | g_loss: 1.7564
# Epoch [    7/   20] | d_loss: 0.2973 | g_loss: 0.4386
# Epoch [    7/   20] | d_loss: 0.2700 | g_loss: 0.6703
# Epoch [    7/   20] | d_loss: 0.2187 | g_loss: 0.3648
# Epoch [    7/   20] | d_loss: 0.1998 | g_loss: 0.5596
# Epoch [    7/   20] | d_loss: 0.3184 | g_loss: 0.7248
# Epoch [    7/   20] | d_loss: 0.2729 | g_loss: 0.5422
# Epoch [    7/   20] | d_loss: 0.2535 | g_loss: 0.7295
# Epoch [    7/   20] | d_loss: 0.2851 | g_loss: 0.5390
# Epoch [    7/   20] | d_loss: 0.3565 | g_loss: 0.4561
# Epoch [    7/   20] | d_loss: 0.2375 | g_loss: 0.6140
# Epoch [    7/   20] | d_loss: 0.3005 | g_loss: 0.6296
# Epoch [    7/   20] | d_loss: 0.2331 | g_loss: 0.4199
# Epoch [    7/   20] | d_loss: 0.2322 | g_loss: 0.5421
# Epoch [    7/   20] | d_loss: 0.3088 | g_loss: 0.5035
# Epoch [    7/   20] | d_loss: 0.2405 | g_loss: 0.8162
# Epoch [    7/   20] | d_loss: 0.5401 | g_loss: 0.8496
# Epoch [    7/   20] | d_loss: 0.2171 | g_loss: 0.8563
# Epoch [    7/   20] | d_loss: 0.3101 | g_loss: 0.4921
# Epoch [    7/   20] | d_loss: 0.2691 | g_loss: 0.4643
# Epoch [    7/   20] | d_loss: 0.3842 | g_loss: 0.8582
# Epoch [    7/   20] | d_loss: 0.2303 | g_loss: 0.5897
# Epoch [    7/   20] | d_loss: 0.2658 | g_loss: 0.5473
# Epoch [    7/   20] | d_loss: 0.2264 | g_loss: 0.2705
# Epoch [    7/   20] | d_loss: 0.3691 | g_loss: 0.5584
# Epoch [    7/   20] | d_loss: 0.3562 | g_loss: 0.3840
# Epoch [    7/   20] | d_loss: 0.3326 | g_loss: 0.8844
# Epoch [    7/   20] | d_loss: 0.2742 | g_loss: 0.7192
# Epoch [    7/   20] | d_loss: 0.3360 | g_loss: 0.8576
# Epoch [    8/   20] | d_loss: 28.2240 | g_loss: 0.1456
# Epoch [    8/   20] | d_loss: 0.2804 | g_loss: 0.7646
# Epoch [    8/   20] | d_loss: 0.3214 | g_loss: 0.4277
# Epoch [    8/   20] | d_loss: 0.4477 | g_loss: 0.3946
# Epoch [    8/   20] | d_loss: 0.4442 | g_loss: 0.3732
# Epoch [    8/   20] | d_loss: 0.4663 | g_loss: 0.1707
# Epoch [    8/   20] | d_loss: 0.5680 | g_loss: 0.2124
# Epoch [    8/   20] | d_loss: 0.4542 | g_loss: 0.3464
# Epoch [    8/   20] | d_loss: 0.4556 | g_loss: 0.2744
# Epoch [    8/   20] | d_loss: 0.4736 | g_loss: 0.3083
# Epoch [    8/   20] | d_loss: 0.4507 | g_loss: 0.2881
# Epoch [    8/   20] | d_loss: 0.5516 | g_loss: 0.3357
# Epoch [    8/   20] | d_loss: 0.5824 | g_loss: 0.2545
# Epoch [    8/   20] | d_loss: 0.4669 | g_loss: 0.2891
# Epoch [    8/   20] | d_loss: 0.4617 | g_loss: 0.2924
# Epoch [    8/   20] | d_loss: 0.5172 | g_loss: 0.2881
# Epoch [    8/   20] | d_loss: 0.4816 | g_loss: 0.3427
# Epoch [    8/   20] | d_loss: 0.4996 | g_loss: 0.3492
# Epoch [    8/   20] | d_loss: 0.5064 | g_loss: 0.3630
# Epoch [    8/   20] | d_loss: 0.4468 | g_loss: 0.3776
# Epoch [    8/   20] | d_loss: 0.4625 | g_loss: 0.2551
# Epoch [    8/   20] | d_loss: 0.4454 | g_loss: 0.2464
# Epoch [    8/   20] | d_loss: 0.4697 | g_loss: 0.3400
# Epoch [    8/   20] | d_loss: 0.4478 | g_loss: 0.3049
# Epoch [    8/   20] | d_loss: 0.4406 | g_loss: 0.3187
# Epoch [    8/   20] | d_loss: 0.5534 | g_loss: 0.2498
# Epoch [    8/   20] | d_loss: 0.5092 | g_loss: 0.3313
# Epoch [    8/   20] | d_loss: 0.4735 | g_loss: 0.3023
# Epoch [    8/   20] | d_loss: 0.4463 | g_loss: 0.2476
# Epoch [    9/   20] | d_loss: 0.5082 | g_loss: 0.2567
# Epoch [    9/   20] | d_loss: 0.4313 | g_loss: 0.3107
# Epoch [    9/   20] | d_loss: 0.5319 | g_loss: 0.2940
# Epoch [    9/   20] | d_loss: 0.4959 | g_loss: 0.3773
# Epoch [    9/   20] | d_loss: 0.5133 | g_loss: 0.3727
# Epoch [    9/   20] | d_loss: 0.4357 | g_loss: 0.3142
# Epoch [    9/   20] | d_loss: 0.5480 | g_loss: 0.3291
# Epoch [    9/   20] | d_loss: 0.4830 | g_loss: 0.2238
# Epoch [    9/   20] | d_loss: 0.4660 | g_loss: 0.2783
# Epoch [    9/   20] | d_loss: 0.4600 | g_loss: 0.4134
# Epoch [    9/   20] | d_loss: 0.4789 | g_loss: 0.3531
# Epoch [    9/   20] | d_loss: 0.4286 | g_loss: 0.2886
# Epoch [    9/   20] | d_loss: 0.5052 | g_loss: 0.4011
# Epoch [    9/   20] | d_loss: 0.4008 | g_loss: 0.3660
# Epoch [    9/   20] | d_loss: 0.3934 | g_loss: 0.7715
# Epoch [    9/   20] | d_loss: 0.3700 | g_loss: 0.3435
# Epoch [    9/   20] | d_loss: 0.5006 | g_loss: 0.4720
# Epoch [    9/   20] | d_loss: 0.4913 | g_loss: 0.3513
# Epoch [   15/   20] | d_loss: 0.1814 | g_loss: 0.5730
# Epoch [   15/   20] | d_loss: 0.2186 | g_loss: 0.6644
# Epoch [   15/   20] | d_loss: 0.2009 | g_loss: 0.6220
# Epoch [   15/   20] | d_loss: 0.1793 | g_loss: 0.6218
# Epoch [   15/   20] | d_loss: 0.2123 | g_loss: 0.7908
# Epoch [   15/   20] | d_loss: 0.1727 | g_loss: 0.7082
# Epoch [   15/   20] | d_loss: 0.1215 | g_loss: 0.8827
# Epoch [   15/   20] | d_loss: 0.1259 | g_loss: 0.5050
# Epoch [   15/   20] | d_loss: 0.1587 | g_loss: 0.7863
# Epoch [   15/   20] | d_loss: 0.1684 | g_loss: 0.9179
# Epoch [   15/   20] | d_loss: 0.2314 | g_loss: 0.9468
# Epoch [   15/   20] | d_loss: 0.2023 | g_loss: 0.6795
# Epoch [   15/   20] | d_loss: 0.1880 | g_loss: 0.7498
# Epoch [   15/   20] | d_loss: 0.2042 | g_loss: 0.6049
# Epoch [   15/   20] | d_loss: 0.1808 | g_loss: 0.7415
# Epoch [   15/   20] | d_loss: 0.2684 | g_loss: 0.6367
# Epoch [   16/   20] | d_loss: 0.1988 | g_loss: 0.9513
# Epoch [   16/   20] | d_loss: 0.1389 | g_loss: 0.7455
# Epoch [   16/   20] | d_loss: 0.1560 | g_loss: 0.6985
# Epoch [   16/   20] | d_loss: 0.2083 | g_loss: 0.7112
# Epoch [   16/   20] | d_loss: 0.2603 | g_loss: 0.7551
# Epoch [   16/   20] | d_loss: 0.2079 | g_loss: 0.9001
# Epoch [   16/   20] | d_loss: 0.1546 | g_loss: 0.9766
# Epoch [   16/   20] | d_loss: 0.1471 | g_loss: 0.8170
# Epoch [   16/   20] | d_loss: 0.1321 | g_loss: 0.7125
# Epoch [   16/   20] | d_loss: 0.1709 | g_loss: 0.6142
# Epoch [   16/   20] | d_loss: 0.1875 | g_loss: 0.6202
# Epoch [   16/   20] | d_loss: 0.1525 | g_loss: 0.5538
# Epoch [   16/   20] | d_loss: 0.1460 | g_loss: 0.8800
# Epoch [   16/   20] | d_loss: 0.1768 | g_loss: 0.6960
# Epoch [   16/   20] | d_loss: 0.1969 | g_loss: 0.6668
# Epoch [   16/   20] | d_loss: 0.2422 | g_loss: 0.4378
# Epoch [   16/   20] | d_loss: 0.1888 | g_loss: 0.7701
# Epoch [   16/   20] | d_loss: 0.1680 | g_loss: 0.8471
# Epoch [   16/   20] | d_loss: 0.2267 | g_loss: 0.5135
# Epoch [   16/   20] | d_loss: 0.1822 | g_loss: 0.6049
# Epoch [   16/   20] | d_loss: 0.1355 | g_loss: 0.7825
# Epoch [   16/   20] | d_loss: 0.2638 | g_loss: 0.6615
# Epoch [   16/   20] | d_loss: 0.1679 | g_loss: 1.2470
# Epoch [   16/   20] | d_loss: 0.1510 | g_loss: 0.5310
# Epoch [   16/   20] | d_loss: 0.1478 | g_loss: 0.6700
# Epoch [   16/   20] | d_loss: 0.1843 | g_loss: 0.9672
# Epoch [   18/   20] | d_loss: 0.1228 | g_loss: 0.6066
# Epoch [   18/   20] | d_loss: 0.1467 | g_loss: 0.9598
# Epoch [   18/   20] | d_loss: 0.1644 | g_loss: 0.7067
# Epoch [   18/   20] | d_loss: 0.1450 | g_loss: 0.8321
# Epoch [   18/   20] | d_loss: 0.1797 | g_loss: 1.0031
# Epoch [   18/   20] | d_loss: 0.1454 | g_loss: 1.0553
# Epoch [   18/   20] | d_loss: 0.1967 | g_loss: 0.9703
# Epoch [   18/   20] | d_loss: 0.1816 | g_loss: 0.7963
# Epoch [   18/   20] | d_loss: 0.1340 | g_loss: 0.8920
# Epoch [   18/   20] | d_loss: 0.1018 | g_loss: 0.6889
# Epoch [   18/   20] | d_loss: 0.1364 | g_loss: 0.9534
# Epoch [   18/   20] | d_loss: 0.1105 | g_loss: 0.8644
# Epoch [   18/   20] | d_loss: 0.1225 | g_loss: 1.0220
# Epoch [   18/   20] | d_loss: 0.2171 | g_loss: 0.5633
# Epoch [   18/   20] | d_loss: 0.1395 | g_loss: 0.8538
# Epoch [   18/   20] | d_loss: 0.1689 | g_loss: 0.5654
# Epoch [   18/   20] | d_loss: 0.1860 | g_loss: 0.7574
# Epoch [   18/   20] | d_loss: 0.1096 | g_loss: 0.6640
# Epoch [   18/   20] | d_loss: 0.2260 | g_loss: 0.9365
# Epoch [   19/   20] | d_loss: 0.4151 | g_loss: 0.8472
# Epoch [   19/   20] | d_loss: 0.2137 | g_loss: 0.5930
# Epoch [   19/   20] | d_loss: 0.1980 | g_loss: 0.5757
# Epoch [   19/   20] | d_loss: 0.1032 | g_loss: 0.7738
# Epoch [   19/   20] | d_loss: 0.1633 | g_loss: 1.0988
# Epoch [   19/   20] | d_loss: 0.2355 | g_loss: 0.7411
# Epoch [   19/   20] | d_loss: 0.1680 | g_loss: 0.9988
# Epoch [   19/   20] | d_loss: 0.1336 | g_loss: 0.6299
# Epoch [   19/   20] | d_loss: 0.1532 | g_loss: 0.9172
# Epoch [   19/   20] | d_loss: 0.2524 | g_loss: 0.8836
# Epoch [   19/   20] | d_loss: 0.1780 | g_loss: 0.6832
# Epoch [   19/   20] | d_loss: 0.1358 | g_loss: 0.6777
# Epoch [   19/   20] | d_loss: 0.1120 | g_loss: 0.8281
# Epoch [   19/   20] | d_loss: 0.2171 | g_loss: 0.9289
# Epoch [   19/   20] | d_loss: 0.3003 | g_loss: 0.7807
# Epoch [   19/   20] | d_loss: 0.1318 | g_loss: 0.6799
# Epoch [   19/   20] | d_loss: 0.1440 | g_loss: 0.9962
# Epoch [   19/   20] | d_loss: 0.1036 | g_loss: 0.7158
# Epoch [   19/   20] | d_loss: 0.1049 | g_loss: 0.9170
# Epoch [   19/   20] | d_loss: 0.1597 | g_loss: 0.5143
# Epoch [   19/   20] | d_loss: 0.2315 | g_loss: 0.6744
# Epoch [   19/   20] | d_loss: 0.1419 | g_loss: 1.0970
# Epoch [   19/   20] | d_loss: 0.1670 | g_loss: 0.6769
# Epoch [   19/   20] | d_loss: 0.2224 | g_loss: 0.7052
# Epoch [   19/   20] | d_loss: 0.1338 | g_loss: 0.7883
# Epoch [   19/   20] | d_loss: 0.2092 | g_loss: 0.7828
# Epoch [   19/   20] | d_loss: 0.1926 | g_loss: 0.7322
# Epoch [   19/   20] | d_loss: 0.3493 | g_loss: 0.7206
# Epoch [   19/   20] | d_loss: 0.1537 | g_loss: 0.7685
# Epoch [   20/   20] | d_loss: 0.1538 | g_loss: 0.7573
# Epoch [   20/   20] | d_loss: 0.1446 | g_loss: 0.6480
# Epoch [   20/   20] | d_loss: 0.1720 | g_loss: 0.7170
# Epoch [   20/   20] | d_loss: 0.1717 | g_loss: 1.1511
# Epoch [   20/   20] | d_loss: 0.1023 | g_loss: 0.9094
# Epoch [   20/   20] | d_loss: 0.1946 | g_loss: 0.5376
# Epoch [   20/   20] | d_loss: 0.1869 | g_loss: 1.0988
# Epoch [   20/   20] | d_loss: 0.2006 | g_loss: 0.9494
# Epoch [   20/   20] | d_loss: 0.1315 | g_loss: 0.7074
# Epoch [   20/   20] | d_loss: 0.1215 | g_loss: 0.9153
# Epoch [   20/   20] | d_loss: 0.1653 | g_loss: 1.0398
# Epoch [   20/   20] | d_loss: 0.1613 | g_loss: 0.8235
# Epoch [   20/   20] | d_loss: 0.1213 | g_loss: 0.7602
# Epoch [   20/   20] | d_loss: 0.1276 | g_loss: 0.7901
# Epoch [   20/   20] | d_loss: 0.1441 | g_loss: 0.8245
# Epoch [   20/   20] | d_loss: 0.1125 | g_loss: 0.9234
# Epoch [   20/   20] | d_loss: 0.1736 | g_loss: 0.6818
# Epoch [   20/   20] | d_loss: 0.1375 | g_loss: 0.8342
# Epoch [   20/   20] | d_loss: 0.1676 | g_loss: 0.9896
# Epoch [   20/   20] | d_loss: 0.1556 | g_loss: 0.6807
# Epoch [   20/   20] | d_loss: 0.1850 | g_loss: 1.3915
# Epoch [   20/   20] | d_loss: 0.2232 | g_loss: 0.7439
# Epoch [   20/   20] | d_loss: 0.1860 | g_loss: 0.8427
# Epoch [   20/   20] | d_loss: 0.1197 | g_loss: 0.7993
# Epoch [   20/   20] | d_loss: 0.1818 | g_loss: 0.9466
# Epoch [   20/   20] | d_loss: 0.2740 | g_loss: 0.6475
# Epoch [   20/   20] | d_loss: 0.2950 | g_loss: 1.0359
# Epoch [   20/   20] | d_loss: 0.1701 | g_loss: 0.7300
# Epoch [   20/   20] | d_loss: 0.1214 | g_loss: 0.8387

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)
#
# - a higher resolution of the input images will probably improve the generated images. 32x32 is quite low. This will also allow to use a deeper Network (with increasing/decreasing depth)
#
# - Maybe the BCE Loss will be better for the Task with label smoothing to get a more generalized model.
#
# - As already mentioned: Make the dataset more diverse
#
# - With the least square loss it seems to make not so much sense to increase the number of training epochs. But a smaller Learning rate could improve the model's performance
#
# - As mentioned in this [paper](https://arxiv.org/pdf/2006.05338.pdf), it could help to use Data Augmentation. Not all input images has the same camera angle, so playing around with some random rotation could help the learning of the generator to capture the distribution of the original set.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
